# %% [markdown]
# # Project 1 - Getting Started

# %% [markdown]
# ### Notebook Setup

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from pandas_profiling import ProfileReport

# %%
# Settings required in new code block due to an error in latest Jupyter version
sns.set()
matplotlib.rcParams["figure.dpi"] = 300
sns.set(font_scale=1.25, rc={"figure.figsize": (20, 10)})
sns.set_style("ticks")  # ticks
sns.set_palette("colorblind")

# %% [markdown]
# ### Load data using Pandas

# %%
data = pd.read_csv("./data/Salaries.csv")

# %%
profile = ProfileReport(data, title='Pandas Profiling Report', html={"style": {"full_width": true}})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-65f915bcc9d7> in <module>
# ----> 1 profile = ProfileReport(data, title='Pandas Profiling Report')
#       2 profile.to_notebook_iframe()
#
# b:\applications\python3\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, minimal, config_file, **kwargs)
#      71         # Build report structure
#      72         self.sample = self.get_sample(df)
# ---> 73         self.report = get_report_structure(self.date, self.sample, description_set)
#      74         self.title = config["title"].get(str)
#      75         self.description_set = description_set
#
# b:\applications\python3\lib\site-packages\pandas_profiling\report\structure\report.py in get_report_structure(date, sample, summary)
#     209             ),
#     210             Sequence(
# --> 211                 get_correlation_items(summary),
#     212                 sequence_type="tabs",
#     213                 name="Correlations",
#
# b:\applications\python3\lib\site-packages\pandas_profiling\report\structure\report.py in get_correlation_items(summary)
#      74         items.append(
#      75             Image(
# ---> 76                 plot.correlation_matrix(item, vmin=vmin),
#      77                 alt=name,
#      78                 anchor_id=key,
#
# b:\applications\python3\lib\site-packages\pandas_profiling\visualisation\plot.py in correlation_matrix(data, vmin)
#     130     plt.subplots_adjust(bottom=0.2)
#     131
# --> 132     return plot_360_n0sc0pe(plt)
#     133
#     134
#
# b:\applications\python3\lib\site-packages\pandas_profiling\visualisation\utils.py in plot_360_n0sc0pe(plt, image_format, attempts)
#      45     try:
#      46         image_data = BytesIO()
# ---> 47         plt.savefig(image_data, dpi=dpi, format=image_format)
#      48         image_data.seek(0)
#      49         result_string = "data:{mime_type};base64,{image_data}".format(
#
# b:\applications\python3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# b:\applications\python3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# b:\applications\python3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# b:\applications\python3\lib\site-packages\matplotlib\backends\backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1200                 detach = True
#    1201
# -> 1202             result = self._print_svg(filename, fh, **kwargs)
#    1203
#    1204             # Detach underlying stream from wrapper so that it remains open in
#
# b:\applications\python3\lib\site-packages\matplotlib\backends\backend_svg.py in _print_svg(self, filename, fh, dpi, bbox_inches_restore, **kwargs)
#    1225             bbox_inches_restore=bbox_inches_restore)
#    1226
# -> 1227         self.figure.draw(renderer)
#    1228         renderer.finalize()
#    1229
#
# b:\applications\python3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# b:\applications\python3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# b:\applications\python3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# b:\applications\python3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# b:\applications\python3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# b:\applications\python3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     156                 image_group.append(a)
#     157             else:
# --> 158                 flush_images()
#     159                 a.draw(renderer)
#     160         flush_images()
#
# b:\applications\python3\lib\site-packages\matplotlib\image.py in flush_images()
#     141         def flush_images():
#     142             if len(image_group) == 1:
# --> 143                 image_group[0].draw(renderer)
#     144             elif len(image_group) > 1:
#     145                 data, l, b = composite_images(image_group, renderer, mag)
#
# b:\applications\python3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# b:\applications\python3\lib\site-packages\matplotlib\image.py in draw(self, renderer, *args, **kwargs)
#     617         else:
#     618             im, l, b, trans = self.make_image(
# --> 619                 renderer, renderer.get_image_magnification())
#     620             if im is not None:
#     621                 renderer.draw_image(gc, l, b, im)
#
# b:\applications\python3\lib\site-packages\matplotlib\image.py in make_image(self, renderer, magnification, unsampled)
#     879         return self._make_image(
#     880             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 881             unsampled=unsampled)
#     882
#     883     def _check_unsampled_image(self, renderer):
#
# b:\applications\python3\lib\site-packages\matplotlib\image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     518             # (of int or float)
#     519             # or an RGBA array of re-sampled input
# --> 520             output = self.to_rgba(output, bytes=True, norm=False)
#     521             # output is now a correctly sized RGBA array of uint8
#     522
#
# b:\applications\python3\lib\site-packages\matplotlib\cm.py in to_rgba(self, x, alpha, bytes, norm)
#     288         if norm:
#     289             x = self.norm(x)
# --> 290         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     291         return rgba
#     292
#
# b:\applications\python3\lib\site-packages\matplotlib\colors.py in __call__(self, X, alpha, bytes)
#     559                 # override its alpha just as for any other value.
#     560
# --> 561         rgba = lut.take(xa, axis=0, mode='clip')
#     562         if vtype == 'scalar':
#     563             rgba = tuple(rgba[0, :])
#
# KeyboardInterrupt:
